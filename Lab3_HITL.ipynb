# %%
# !pip install langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 4.3 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
from google.colab import userdata

GROQ_API_KEY = userdata.get("GROQ_API_KEY")

llm = ChatGroq(
    api_key=GROQ_API_KEY,
    model="llama-3.1-8b-instant",
    temperature=0.3
)

print("✅ Model connected successfully")
# Out:
# ✅ Model connected successfully

# %%
task = "Write a short polite email asking my professor for a deadline extension."

draft = llm.invoke(task).content

print("----- DRAFT EMAIL -----")
print(draft)
# Out:
# ----- DRAFT EMAIL -----
# Here's a sample email you can use:
#
# Subject: Request for Deadline Extension for [Assignment/Project Name]
#
# Dear Professor [Professor's Name],
#
# I hope this email finds you well. I am writing to request a deadline extension for the [Assignment/Project Name] that is due on [Original Due Date]. Due to [briefly mention a valid reason, e.g., personal circumstances, academic commitments, or unforeseen challenges], I require some additional time to complete the assignment to the best of my abilities.
#
# I am confident that with a brief extension, I will be able to submit quality work that meets your expectations. I am estimating that I will need an additional [Specific Number of Days] to complete the assignment.
#
# Would it be possible to discuss this further and potentially adjust the deadline to [New Due Date]? I appreciate your understanding and flexibility in this matter.
#
# Thank you for your time and consideration.
#
# Sincerely,
# [Your Name]

# %%
decision = input("Type APPROVED to send, or anything else to reject: ")

if decision.strip().upper() == "APPROVED":
    print("✅ Email sent!")
else:
    print("❌ Not sent. The draft was rejected.")
# Out:
# Type APPROVED to send, or anything else to reject: yes
# ❌ Not sent. The draft was rejected.
