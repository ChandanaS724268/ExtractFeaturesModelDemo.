# %%
# !pip install langchain langchain-groq langsmith -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.6 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# Get keys from Colab Secrets
GROQ_API_KEY = userdata.get("GROQ_API_KEY")
LANGSMITH_API_KEY = userdata.get("LANGSMITH_API_KEY")

# Enable LangSmith tracing
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = LANGSMITH_API_KEY
os.environ["LANGCHAIN_PROJECT"] = "Lab9-Agentic-AI"

print("✅ LangSmith tracing enabled")
# Out:
# ✅ LangSmith tracing enabled

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key=GROQ_API_KEY,
    model="llama-3.1-8b-instant",
    temperature=0
)

question = """
A shop sells pens at 12 rupees each.
If I buy 7 and pay with 100, how much change?
Explain the calculation.
"""

response = llm.invoke(question)

print(response.content)
# Out:
# To find the change, we need to calculate the total cost of the pens and subtract that from the amount you paid.
#
# 1. Calculate the total cost of the pens:
#    Number of pens: 7
#    Price per pen: 12 rupees
#    Total cost = Number of pens * Price per pen
#    Total cost = 7 * 12
#    Total cost = 84 rupees
#
# 2. Calculate the change:
#    Amount paid: 100 rupees
#    Total cost: 84 rupees
#    Change = Amount paid - Total cost
#    Change = 100 - 84
#    Change = 16 rupees
#
# So, you will get a change of 16 rupees.
